# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
meter = pd.read_csv('combined_data.csv')
meter.head()
# Out:
#    Unnamed: 0 meter_id                       w_timestamp  current  voltage  \
# 0           0   OND023  2022-07-12 13:57:30.449294+00:00     0.79    210.1
# 1           1   OND023  2022-07-12 13:58:42.793010+00:00     0.80    210.6
# 2           2   OND023  2022-07-12 14:00:28.080361+00:00     0.85    208.3
# 3           3   OND023  2022-07-12 14:01:00.914557+00:00     0.74    208.5
# 4           4   OND023  2022-07-12 14:01:34.931821+00:00     0.74    208.1
#
#    frequency  power_factor    energy  real_power  reactive_power  \
# 0       50.1          0.75       NaN    0.124484        0.109785
# 1       50.0          0.75  0.002539    0.126360        0.111439
# 2       50.0          0.74  0.003832    0.131021        0.119088
# 3       50.0          0.76  0.001069    0.117260        0.100277
# 4       49.9          0.76  0.001106    0.117035        0.100084
#
#    apparent_power       tita  hour  time_diff
# 0        0.165979  41.409622    14   0.009675
# ...

# %%
meter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306708 entries, 0 to 306707
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0      306708 non-null  int64
#  1   meter_id        306708 non-null  object
#  2   w_timestamp     306708 non-null  object
#  3   current         306708 non-null  float64
#  4   voltage         306708 non-null  float64
#  5   frequency       306708 non-null  float64
#  6   power_factor    306708 non-null  float64
#  7   energy          306705 non-null  float64
#  8   real_power      306708 non-null  float64
#  9   reactive_power  306708 non-null  float64
#  10  apparent_power  306708 non-null  float64
#  11  tita            306708 non-null  float64
#  12  hour            306708 non-null  int64
#  13  time_diff       306708 non-null  float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 32.8+ MB

# %%
meter.duplicated().sum()
# Out:
# 0

# %%
meter = meter.iloc[:,1:]

# %%
meter.head()
# Out:
#   meter_id                       w_timestamp  current  voltage  frequency  \
# 0   OND023  2022-07-12 13:57:30.449294+00:00     0.79    210.1       50.1
# 1   OND023  2022-07-12 13:58:42.793010+00:00     0.80    210.6       50.0
# 2   OND023  2022-07-12 14:00:28.080361+00:00     0.85    208.3       50.0
# 3   OND023  2022-07-12 14:01:00.914557+00:00     0.74    208.5       50.0
# 4   OND023  2022-07-12 14:01:34.931821+00:00     0.74    208.1       49.9
#
#    power_factor    energy  real_power  reactive_power  apparent_power  \
# 0          0.75       NaN    0.124484        0.109785        0.165979
# 1          0.75  0.002539    0.126360        0.111439        0.168480
# 2          0.74  0.003832    0.131021        0.119088        0.177055
# 3          0.76  0.001069    0.117260        0.100277        0.154290
# 4          0.76  0.001106    0.117035        0.100084        0.153994
#
#         tita  hour  time_diff
# 0  41.409622    14   0.009675
# 1  41.409622    14   0.009675
# ...

# %% [markdown]
# converting data types

# %%
meter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306708 entries, 0 to 306707
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   meter_id        306708 non-null  object
#  1   w_timestamp     306708 non-null  object
#  2   current         306708 non-null  float64
#  3   voltage         306708 non-null  float64
#  4   frequency       306708 non-null  float64
#  5   power_factor    306708 non-null  float64
#  6   energy          306705 non-null  float64
#  7   real_power      306708 non-null  float64
#  8   reactive_power  306708 non-null  float64
#  9   apparent_power  306708 non-null  float64
#  10  tita            306708 non-null  float64
#  11  hour            306708 non-null  int64
#  12  time_diff       306708 non-null  float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 30.4+ MB

# %%
meter['w_timestamp'] = pd.to_datetime(meter['w_timestamp'])

# %%
meter.isna().sum()
# Out:
# meter_id          0
# w_timestamp       0
# current           0
# voltage           0
# frequency         0
# power_factor      0
# energy            3
# real_power        0
# reactive_power    0
# apparent_power    0
# tita              0
# hour              0
# time_diff         0
# dtype: int64

# %%
meter.dropna(axis=0, inplace=True)

# %%
meter.isna().sum()
# Out:
# meter_id          0
# w_timestamp       0
# current           0
# voltage           0
# frequency         0
# power_factor      0
# energy            0
# real_power        0
# reactive_power    0
# apparent_power    0
# tita              0
# hour              0
# time_diff         0
# dtype: int64

# %%
meter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 306705 entries, 1 to 306707
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   meter_id        306705 non-null  object
#  1   w_timestamp     306705 non-null  datetime64[ns, UTC]
#  2   current         306705 non-null  float64
#  3   voltage         306705 non-null  float64
#  4   frequency       306705 non-null  float64
#  5   power_factor    306705 non-null  float64
#  6   energy          306705 non-null  float64
#  7   real_power      306705 non-null  float64
#  8   reactive_power  306705 non-null  float64
#  9   apparent_power  306705 non-null  float64
#  10  tita            306705 non-null  float64
#  11  hour            306705 non-null  int64
#  12  time_diff       306705 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(10), int64(1), object(1)
# memory usage: 32.8+ MB

# %%
meter['meter_id'].value_counts()
# Out:
# OND023    161083
# OYO021     69910
# OND021     48163
# OND024     27549
# Name: meter_id, dtype: int64

# %%
ond023 = meter[meter['meter_id'] == 'OND023']
oyo021 = meter[meter['meter_id'] == "OYO021"]
ond021 = meter[meter['meter_id'] == 'OND021']
ond024 = meter[meter['meter_id'] == 'OND024']

# %%
ond023
# Out:
#        meter_id                      w_timestamp  current  voltage  frequency  \
# 1        OND023 2022-07-12 13:58:42.793010+00:00     0.80    210.6       50.0
# 2        OND023 2022-07-12 14:00:28.080361+00:00     0.85    208.3       50.0
# 3        OND023 2022-07-12 14:01:00.914557+00:00     0.74    208.5       50.0
# 4        OND023 2022-07-12 14:01:34.931821+00:00     0.74    208.1       49.9
# 5        OND023 2022-07-12 14:02:10.738666+00:00     0.75    208.1       49.9
# ...         ...                              ...      ...      ...        ...
# 161079   OND023 2022-10-22 21:35:34.272836+00:00     1.92    229.1       49.9
# 161080   OND023 2022-10-22 21:36:08.484019+00:00     1.63    229.1       49.9
# 161081   OND023 2022-10-22 21:36:43.545834+00:00     1.62    229.5       50.0
# 161082   OND023 2022-10-22 21:38:28.735422+00:00     1.50    230.9       50.1
# 161083   OND023 2022-10-22 21:39:03.565032+00:00     1.54    231.0       50.1
#
# ...

# %%
print('OND023')
min_ = ond023.w_timestamp.min() 
print(min_)
max_ = ond023.w_timestamp.max()
print(max_)
print(max_ - min_)
# Out:
# OND023
# 2022-07-12 13:58:42.793010+00:00
# 2022-10-22 21:39:03.565032+00:00
# 102 days 07:40:20.772022

# %%
print('OND021')
min_ = ond021.w_timestamp.min()
print(min_)
max_ = ond021.w_timestamp.max()
print(max_)
print(max_ - min_)
# Out:
# OND021
# 2022-08-01 16:36:36.631509+00:00
# 2022-08-25 19:51:52.091233+00:00
# 24 days 03:15:15.459724

# %%
print('OND024')
min_ = ond024.w_timestamp.min()
print(min_)
max_ = ond024.w_timestamp.max()
print(max_)
print(max_ - min_)
# Out:
# OND024
# 2022-08-02 14:15:12.285346+00:00
# 2022-10-23 12:26:55.581190+00:00
# 81 days 22:11:43.295844

# %%
print('OYO021')
min_ = oyo021.w_timestamp.min()
print(min_)
max_ = oyo021.w_timestamp.max() 
print(max_)
print(max_ - min_)
# Out:
# OYO021
# 2022-07-12 13:58:47.803621+00:00
# 2022-10-21 13:35:10.749704+00:00
# 100 days 23:36:22.946083

# %% [markdown]
# **OND023**

# %%
ond023['w_timestamp']
# Out:
# 1        2022-07-12 13:58:42.793010+00:00
# 2        2022-07-12 14:00:28.080361+00:00
# 3        2022-07-12 14:01:00.914557+00:00
# 4        2022-07-12 14:01:34.931821+00:00
# 5        2022-07-12 14:02:10.738666+00:00
#                        ...
# 161079   2022-10-22 21:35:34.272836+00:00
# 161080   2022-10-22 21:36:08.484019+00:00
# 161081   2022-10-22 21:36:43.545834+00:00
# 161082   2022-10-22 21:38:28.735422+00:00
# 161083   2022-10-22 21:39:03.565032+00:00
# Name: w_timestamp, Length: 161083, dtype: datetime64[ns, UTC]

# %%
ondo = ond023.copy()

# %%
ondo.set_index('w_timestamp',inplace=True)

# %%
ondo_07 = ondo.loc['2022-07-12']

# %%
ondo.index.day
# Out:
# Int64Index([12, 12, 12, 12, 12, 12, 12, 12, 12, 12,
#             ...
#             22, 22, 22, 22, 22, 22, 22, 22, 22, 22],
#            dtype='int64', name='w_timestamp', length=161083)

# %%
ondo.index.date
# Out:
# array([datetime.date(2022, 7, 12), datetime.date(2022, 7, 12),
#        datetime.date(2022, 7, 12), ..., datetime.date(2022, 10, 22),
#        datetime.date(2022, 10, 22), datetime.date(2022, 10, 22)],
#       dtype=object)

# %%
ondo
# Out:
#                                  meter_id  current  voltage  frequency  \
# w_timestamp
# 2022-07-12 13:58:42.793010+00:00   OND023     0.80    210.6       50.0
# 2022-07-12 14:00:28.080361+00:00   OND023     0.85    208.3       50.0
# 2022-07-12 14:01:00.914557+00:00   OND023     0.74    208.5       50.0
# 2022-07-12 14:01:34.931821+00:00   OND023     0.74    208.1       49.9
# 2022-07-12 14:02:10.738666+00:00   OND023     0.75    208.1       49.9
# ...                                   ...      ...      ...        ...
# 2022-10-22 21:35:34.272836+00:00   OND023     1.92    229.1       49.9
# 2022-10-22 21:36:08.484019+00:00   OND023     1.63    229.1       49.9
# 2022-10-22 21:36:43.545834+00:00   OND023     1.62    229.5       50.0
# 2022-10-22 21:38:28.735422+00:00   OND023     1.50    230.9       50.1
# 2022-10-22 21:39:03.565032+00:00   OND023     1.54    231.0       50.1
#
#                                   power_factor    energy  real_power  \
# w_timestamp
# ...

# %%
plt.hist(ondo['current']);

# %%
ondo
# Out:
#                                  meter_id  current  voltage  frequency  \
# w_timestamp
# 2022-07-12 13:58:42.793010+00:00   OND023     0.80    210.6       50.0
# 2022-07-12 14:00:28.080361+00:00   OND023     0.85    208.3       50.0
# 2022-07-12 14:01:00.914557+00:00   OND023     0.74    208.5       50.0
# 2022-07-12 14:01:34.931821+00:00   OND023     0.74    208.1       49.9
# 2022-07-12 14:02:10.738666+00:00   OND023     0.75    208.1       49.9
# ...                                   ...      ...      ...        ...
# 2022-10-22 21:35:34.272836+00:00   OND023     1.92    229.1       49.9
# 2022-10-22 21:36:08.484019+00:00   OND023     1.63    229.1       49.9
# 2022-10-22 21:36:43.545834+00:00   OND023     1.62    229.5       50.0
# 2022-10-22 21:38:28.735422+00:00   OND023     1.50    230.9       50.1
# 2022-10-22 21:39:03.565032+00:00   OND023     1.54    231.0       50.1
#
#                                   power_factor    energy  real_power  \
# w_timestamp
# ...

# %%
ondo.index.time
# Out:
# array([datetime.time(13, 58, 42, 793010), datetime.time(14, 0, 28, 80361),
#        datetime.time(14, 1, 0, 914557), ...,
#        datetime.time(21, 36, 43, 545834),
#        datetime.time(21, 38, 28, 735422),
#        datetime.time(21, 39, 3, 565032)], dtype=object)

# %%
ondo['hour'] = ondo.index.hour

# %%
ondo
# Out:
#                                  meter_id  current  voltage  frequency  \
# w_timestamp
# 2022-07-12 13:58:42.793010+00:00   OND023     0.80    210.6       50.0
# 2022-07-12 14:00:28.080361+00:00   OND023     0.85    208.3       50.0
# 2022-07-12 14:01:00.914557+00:00   OND023     0.74    208.5       50.0
# 2022-07-12 14:01:34.931821+00:00   OND023     0.74    208.1       49.9
# 2022-07-12 14:02:10.738666+00:00   OND023     0.75    208.1       49.9
# ...                                   ...      ...      ...        ...
# 2022-10-22 21:35:34.272836+00:00   OND023     1.92    229.1       49.9
# 2022-10-22 21:36:08.484019+00:00   OND023     1.63    229.1       49.9
# 2022-10-22 21:36:43.545834+00:00   OND023     1.62    229.5       50.0
# 2022-10-22 21:38:28.735422+00:00   OND023     1.50    230.9       50.1
# 2022-10-22 21:39:03.565032+00:00   OND023     1.54    231.0       50.1
#
#                                   power_factor    energy  real_power  \
# w_timestamp
# ...

# %%
ondo.groupby(ondo.index.date).mean()
# Out:
#              current     voltage  frequency  power_factor    energy  \
# 2022-07-12  1.264767  215.932616  50.142055      0.789415  0.002804
# 2022-07-13  1.015747  223.766957  50.149153      0.751673  0.002227
# 2022-07-14  0.917851  222.114286  50.058425      0.795661  0.001771
# 2022-07-15  1.008921  216.058370  49.967885      0.783357  0.001913
# 2022-07-16  1.221234  225.435680  49.934767      0.792342  0.002430
# ...              ...         ...        ...           ...       ...
# 2022-10-18  0.597659  231.221303  49.963569      0.854003  0.001357
# 2022-10-19  0.193119  239.182798  49.995309      0.290683  0.000379
# 2022-10-20  0.905805  240.623139  49.981891      0.816429  0.002096
# 2022-10-21  0.818501  226.289117  50.038193      0.543963  0.002367
# 2022-10-22  1.305150  227.839530  49.985043      0.732009  0.003383
#
#             real_power  reactive_power  apparent_power       tita       hour  \
# ...

# %%
ondo.groupby(ondo.index.month).mean()
# Out:
#               current     voltage  frequency  power_factor    energy  \
# w_timestamp
# 7            1.052426  229.603015  50.043440      0.789489  0.002410
# 8            1.107724  234.783075  50.166083      0.787755  0.002953
# 9            1.294148  235.149643  50.113146      0.805093  0.005263
# 10           1.317924  234.849531  50.037794      0.765828  0.005099
#
#              real_power  reactive_power  apparent_power       tita       hour  \
# w_timestamp
# 7              0.198379        0.128640        0.241760  36.146011  12.414564
# 8              0.208744        0.146788        0.260404  36.555659  12.486310
# 9              0.256227        0.157223        0.303934  34.815165  12.729762
# 10             0.254921        0.164360        0.308773  37.779895  12.254711
#
#              time_diff
# w_timestamp
# 7             0.009675
# 8             0.009675
# 9             0.009675
# 10            0.009675

# %%
ondo.shape
# Out:
# (161083, 12)

# %%
plt.figure(figsize=[8,8])
sns.heatmap(ondo.corr(), annot = True);

# %%
plt.hist(ondo['energy']);

# %%
plt.hist(ondo['current']);

# %%
plt.hist(ondo['voltage']);

# %%
ondo.skew(numeric_only=True)
# Out:
# current             2.336031
# voltage            -0.512830
# frequency          -0.226076
# power_factor       -1.530984
# energy            159.885407
# real_power          2.609177
# reactive_power      1.438171
# apparent_power      2.339627
# tita                0.358579
# hour               -0.003529
# time_diff           0.000000
# dtype: float64

# %%
ondo['real_power']
# Out:
# w_timestamp
# 2022-07-12 13:58:42.793010+00:00    0.126360
# 2022-07-12 14:00:28.080361+00:00    0.131021
# 2022-07-12 14:01:00.914557+00:00    0.117260
# 2022-07-12 14:01:34.931821+00:00    0.117035
# 2022-07-12 14:02:10.738666+00:00    0.117056
#                                       ...
# 2022-10-22 21:35:34.272836+00:00    0.395885
# 2022-10-22 21:36:08.484019+00:00    0.347293
# 2022-10-22 21:36:43.545834+00:00    0.345765
# 2022-10-22 21:38:28.735422+00:00    0.259763
# 2022-10-22 21:39:03.565032+00:00    0.263248
# Name: real_power, Length: 161083, dtype: float64
